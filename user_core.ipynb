# %% [markdown]
# # user_profile
#
# ## administrative_identity
# - **Name:** Florian Fendt, Nickname: Flo
# - **Date and place of birth** 1989-10-08, Munich, Germany
#
# ## background
# ### education
# - Studied at LMU from 2011 until 2018, graduated with an M.Sc. in Statistics. Spezialized in machine learning, Master grade: 1.7
# * [2026-04-13] * education: Advanced studies in AI System Architecture and Python-based automation (Project V8).
# * [2026-04-14] Automatisierung des Scribe-Workflows abschließen
# * [2026-04-14] Lebt in München, arbeitet remote
#
# ### working_experience
# - 3 years part time during master studies, working at ML department: tutoring and co developing R package mlr at that time (until 2017)
# - 8 years gastronomy, all positions in front and back of house:
#   - Can do everything in kitchen including Head of Cuisine
#   - Barkeeping: Also night barkeeper but stronger in Barista skills
#   - Chef de Rang, Duty Manager expert
# - Various short term workplaces in tourism, craftmenships, office work
#
# ### goals
# - Career shift from gastronomy to Python Development & AI System Architecture.
# ### life_context
# - The users son is: Levi Matthias Fendt (*23.12.2023).
#
#
# ## professional_skills
# ### languages
# - Beginner in **Python** (High priority), basic Markdown, medium CSS. Profound but old knowledge of R.
# * [2026-04-13] * languages: Growing proficiency in Python (File-I/O, JSON parsing, Pathlib logic).
# * tools: Expertise in Rclone (Staging & Sync), Bash-scripting for Sync-Manager orchestration.
# * communication_style: Direct, logical, and technical. Values 'Team Spirit' and collaborative problem-solving.
# *
#
# ### tools
# - Experience with Rclone (Sync), Linux basics, git(hub)
#
#
# ### communication_style
# - Florian values variety and natural flow. Avoid repetitive greeting patterns (like starting every message with "Moin"). A mix of situational greetings, "Servus", or direct entries into the topic is preferred to maintain a dynamic interaction.
#
#
# ## user_insights
# - **The "Why" Protocol:** Florian frequently asks for the reasoning behind AI decisions. Explanations must be technical and logical.
# - **Anti-Bias:** User prefers anti-biased honest communication.
# - **Learning Style:** Prefers "Learning by Building" (Architecture first, then Code).
# - **Skillset:** Strong conceptual understanding of architecture (separation of Mirror, Vault, and Workspace). Currently learning the syntax layer (Python).
# - **Working Style:** Highly collaborative ("Team Spirit"). Prefers transparency ("Tell me where it is") over "black-box" solutions.
# - **Mindset:** Pragmatic. Desires "Quick Wins" (CLI Chat) without losing sight of the ultimate goal (Bot Automation). Unafraid of "Bleeding Edge" technology (Gemini 3.1).
# - **Challenge:** Needs to bridge the gap between logical statistical thinking and rigorous Python syntax.
# * [2026-04-13] Flo operates on the 'Learning by Building' principle. He prioritizes transparency ('The Why Protocol') over black-box solutions and challenges system architecture logic to ensure scalability and robustness.

# %% [markdown]
# # standards.md
#
# ## 01 conventions
#
# ### 01.01 general file rules
# - **Naming Syntax:** All files and folders must be `lowercase`, using `snake_case`, and strictly **no spaces**.
# - **Dates:** Use `YYYY-MM-DD` (e.g., `log_2026-03-25.md`).
# - **Versioning:** No version numbers in filenames (handled via git/internal headers).
#
# ### 01.02 specific formats
# - **Text & Documentation:** Use `.md` (Markdown). UTF-8 encoding.
# - **Structured Data:** Use `.csv`. Separator: Semicolon (`;`). Headers in `snake_case`.
# - **Logic & Scripts:** Use `.py` (Python). Follow PEP 8. Use `docstrings`.
# - **Web Development:** `.html` (semantic tags) and `.css` (kebab-case for classes).
# - **Data Exchange:** `.json`. Keys in `snake_case`. Indent: 2.
#
# ## 02 standards
#
# ### 02.01 markdown_standards
# - **Line 1:** Must be H1 with exact filename: `# filename.extension`.
# - **Level 2 Headlines:** Must be numbered: `## 01 [Title]`, `## 02 [Title]`.
# - **Level 3 Headlines:** No numbering required.
# - **Tables:** Mandatory for lists with >3 attributes per item.
# - **Relational Logic:** Use `->` for flow and `decision:` for binding results.
#
# ### 02.02 python_standards
# - **Style Guide:** Follow **PEP 8**.
# - **Naming:** `snake_case` for variables, functions, and files.
# - **Paths:** Use `pathlib` for OS-independent path handling. Use relative paths.
# - **Documentation:** Every function needs a short `docstring` (Summary, Args, Returns).
# - **Structure:** `if __name__ == "__main__":` block for executable scripts.
#
# ### 02.03 web_standards
# - **HTML:** Use **HTML5 semantic tags** (`<main>`, `<section>`, `<nav>`).
# - **CSS:**
#   - Use **kebab-case** for classes and IDs (e.g., `.nav-bar`).
#   - Use variables (`:root`) for colors/spacing to ensure consistency.
# - **Separation:** Keep HTML, CSS, and JS in separate files.
#
# ### 02.04 json_standards
# - **Keys:** Use `snake_case` for all keys.
# - **Formatting:** Use `indent=2` for human readability.
# - **Types:** Strict typing; no mixing of types in lists.
#
# ### 02.05 language standards
# - **System Language:** All file content (Logic, Docs, Comments) must be in **ENGLISH**.
# - **Interaction Language:** Chat and "Chain of Thought" must be in **GERMAN**.
